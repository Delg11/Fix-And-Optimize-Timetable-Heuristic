# %%
# import pandas as pd
# from openpyxl.styles import PatternFill
# import random
# from pulp import LpVariable, LpProblem, LpMinimize, lpSum, LpStatus, PULP_CBC_CMD
import pandas as pd
import random
from pulp import LpVariable, LpProblem, LpMinimize, lpSum, LpStatus, PULP_CBC_CMD
from openpyxl.styles import PatternFill


# Função para construir o DataFrame df_assigned com os resultados do solver
def build_df_assigned(teachers, classes, periods, x, teacher_id_to_name):
    results = []
    for i in teachers:
        for j in classes:
            for k in periods:
                if x[i][j][k].varValue == 1:  # Condição de atribuição: a aula foi marcada
                    results.append({'Teacher': teacher_id_to_name[i], 'Class': j, 'Period': k})
    df_assigned = pd.DataFrame(results)
    return df_assigned

# Função para mapear períodos para dias da semana e números de períodos diários
def period_to_day_period(period):
    day = (period - 1) // 10
    daily_period = (period - 1) % 10 + 1
    return day, daily_period

# Função para obter uma cor aleatória em formato RGB
def get_random_color(pastel_factor=0.5):
    return [(x + pastel_factor) / (1.0 + pastel_factor) for x in [random.uniform(0, 1.0) for _ in range(3)]]

# Função para calcular a distância entre duas cores
def color_distance(c1, c2):
    return sum([abs(x[0] - x[1]) for x in zip(c1, c2)])


# Função para gerar uma nova cor que seja visualmente distinta das cores existentes
# Crédito: https://gist.github.com/adewes/5884820
def generate_new_color(existing_colors, pastel_factor=0.5):
    max_distance = None
    best_color = None
    for _ in range(100):
        color = get_random_color(pastel_factor=pastel_factor)
        if not existing_colors:
            return color
        best_distance = min([color_distance(color, c) for c in existing_colors])
        if not max_distance or best_distance > max_distance:
            max_distance = best_distance
            best_color = color
    return best_color

# Função para converter uma cor RGB em hexadecimal
def rgb_to_hex(color):
    return ''.join(f'{int(x * 255):02X}' for x in color)

# Função para gerar a timetable colorida e salvar em Excel
def generate_timetable_excel(df_assigned, teacher_id_to_name, excel_filename):
    # Lista dos dias da semana
    days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
    classes = ['6oA', '6oB', '7oA', '7oB', '8oA', '8oB','9oA', '9oB', '1oA', '1oB','2oA', '2oB', '3o']
    
    # Mapear períodos para dias da semana e número do período como feito anteriormente
    df_assigned['Day'], df_assigned['DailyPeriod'] = zip(*df_assigned['Period'].apply(period_to_day_period))
    df_assigned['Day'] = df_assigned['Day'].apply(lambda x: days_of_week[x])
    df_assigned['Day'] = pd.Categorical(df_assigned['Day'], categories=days_of_week, ordered=True)
    df_assigned['Class'] = pd.Categorical(df_assigned['Class'], categories=classes, ordered=True)
    
    # Organizando os dados no formato de timetable
    timetable = df_assigned.pivot_table(index=['Day', 'DailyPeriod'], columns='Class', values='Teacher', aggfunc='first', observed=False).fillna('')

    
    # Atribuição de cores aos professores
    unique_teachers = df_assigned['Teacher'].unique()
    existing_colors = []
    teacher_color_map = {}
    for teacher in unique_teachers:
        new_color = generate_new_color(existing_colors)
        existing_colors.append(new_color)
        teacher_color_map[teacher] = rgb_to_hex(new_color)

    # Exportando para Excel com cores
    with pd.ExcelWriter(excel_filename, engine='openpyxl') as writer:
        timetable.to_excel(writer, sheet_name='Timetable')
        workbook = writer.book
        worksheet = writer.sheets['Timetable']

        # Aplicando cores às células do Excel
        for row in worksheet.iter_rows(min_row=2, min_col=2):
            for cell in row:
                teacher = cell.value
                if teacher and teacher in teacher_color_map:
                    fill_color = teacher_color_map[teacher]
                    cell.fill = PatternFill(start_color=fill_color, end_color=fill_color, fill_type="solid")

    print(f"Arquivo Excel salvo como {excel_filename}")

# Função que executa todas as etapas: constrói o DataFrame df_assigned, gera e exporta a timetable em Excel
def generate_and_export_timetable(teachers, classes, periods, x, dados, excel_filename):
    # Construir o mapeamento de ID do professor para o nome do professor
    teacher_id_to_name = dict(zip(dados['No'], dados['Professor']))

    # Construir o DataFrame df_assigned com os resultados do solver
    df_assigned = build_df_assigned(teachers, classes, periods, x, teacher_id_to_name)

    # Gerar e exportar a timetable em Excel com cores
    generate_timetable_excel(df_assigned, teacher_id_to_name, excel_filename)
def generate_and_export_timetableFO(teachers, classes, periods, x, dados, excel_filename,df_assigned):
    # Construir o mapeamento de ID do professor para o nome do professor
    teacher_id_to_name = dict(zip(dados['No'], dados['Professor']))

    # Gerar e exportar a timetable em Excel com cores
    generate_timetable_excel(df_assigned, teacher_id_to_name, excel_filename)

# Exemplo de uso:
# Supondo que você tenha teachers, classes, periods, x e dados definidos
# generate_and_export_timetable(teachers, classes, periods, x, dados, 'timetable_colored.xlsx')

def avaliar_solucao(solution):
    idle_periods = 0
    double_classes = 0
    triple_classes = 0

    for i in teachers:
        for day_start in range(1, 50, 10):
            periods_day = sorted(set(p for j in classes for p in range(day_start, day_start + 10) if solution[i][j][p].varValue == 1))
            
            # Verificar períodos ociosos
            if periods_day:
                for p in range(day_start, day_start + 10):
                    if p not in periods_day:
                        previous_class = any(pp < p for pp in periods_day)
                        next_class = any(pp > p for pp in periods_day)
                        if previous_class and next_class:
                            idle_periods += 1
            
            # Verificar classes consecutivas
            for j in classes:
                for k in range(day_start, day_start + 9):
                    if solution[i][j][k].varValue == 1 and solution[i][j][k + 1].varValue == 1:
                        double_classes += 1
                        if k + 2 <= day_start + 9 and solution[i][j][k + 2].varValue == 1:
                            triple_classes += 1
    fo=1000*idle_periods - 500*double_classes + 5000*triple_classes;
    return idle_periods, double_classes, triple_classes, fo


def improve_solution(solution, teachers, classes):
    idle_periods, double_classes, triple_classes, fo = avaliar_solucao(solution)
    improved = True
    while improved:
        improved = False
        for teacher1 in teachers:
            for teacher2 in teachers:
                if teacher1 != teacher2:
                    for k in range(1, 49):  # Ajustado para evitar acessar k+1 no último período
                        for class1 in classes:
                            for class2 in classes:
                                if class1 != class2:
                                    # Verifica se as condições de troca são atendidas
                                    if (solution[teacher1][class1][k].varValue == 1 and
                                        solution[teacher1][class2][k + 1].varValue == 1 and
                                        solution[teacher2][class2][k].varValue == 1 and
                                        solution[teacher2][class1][k + 1].varValue == 1):
                                        # print(f"Trocando: teacher1={teacher1}, teacher2={teacher2}, class1={class1}, class2={class2}")
                                        # Troca as classes class1 e class2 nos professores teacher1 e teacher2
                                        solution[teacher1][class1][k].varValue = 0
                                        solution[teacher1][class2][k + 1].varValue = 0
                                        solution[teacher2][class2][k].varValue = 0
                                        solution[teacher2][class1][k + 1].varValue = 0
                                        solution[teacher1][class2][k].varValue = 1
                                        solution[teacher1][class1][k + 1].varValue = 1
                                        solution[teacher2][class1][k].varValue = 1
                                        solution[teacher2][class2][k + 1].varValue = 1

                                        # Avalia a solução após a troca
                                        new_idle_periods, new_double_classes, new_triple_classes,_ = avaliar_solucao(solution)

                                        # Verifica se a troca melhorou a solução
                                        if new_double_classes > double_classes or new_idle_periods < idle_periods:
                                        # if new_double_classes > double_classes or (new_double_classes == double_classes and new_idle_periods < idle_periods):
                                            idle_periods = new_idle_periods
                                            double_classes = new_double_classes
                                            triple_classes = new_triple_classes
                                            improved = True
                                        else:
                                            # Desfaz a troca se não melhorou a solução
                                            solution[teacher1][class2][k].varValue = 0
                                            solution[teacher1][class1][k + 1].varValue = 0
                                            solution[teacher2][class1][k].varValue = 0
                                            solution[teacher2][class2][k + 1].varValue = 0
                                            solution[teacher1][class1][k].varValue = 1
                                            solution[teacher1][class2][k + 1].varValue = 1
                                            solution[teacher2][class2][k].varValue = 1
                                            solution[teacher2][class1][k + 1].varValue = 1

    return solution, idle_periods, double_classes, triple_classes

# # Exemplo de uso
# improved_solution, new_idle_periods, new_double_classes, new_triple_classes = improve_solution(x, teachers, classes)
# print("Idle Periods after improvement:", new_idle_periods)
# print("Double Classes after improvement:", new_double_classes)
# print("Triple Classes after improvement:", new_triple_classes)



def optimize_teacher_assignment(double_classes_cost,idle_periods_cost,triple_classes_cost,teachers, classes_opt, classes, periods, costs, valores_x_opt, availability, teaching_load, ex_opt_groups, timeout=60):
    # Definir as variáveis de decisão
    M=1000000
    x_opt = LpVariable.dicts("x_opt", (teachers, classes_opt, periods), cat=LpBinary)
    idle_periods_var = LpVariable.dicts("idle count", (teachers, range(1, 51)), cat=LpBinary)
    z = LpVariable.dicts("z", (teachers, range(1, 51)), cat=LpBinary)
    y = LpVariable.dicts("y", (teachers, range(1, 51)), cat=LpBinary)
    pc = LpVariable.dicts("pc", (teachers, range(1, 51)), cat=LpBinary)
    nc = LpVariable.dicts("nc", (teachers, range(1, 51)), cat=LpBinary)
    ib = LpVariable.dicts("ib", (teachers, range(1, 51)), cat=LpBinary)
    is_busy = LpVariable.dicts("is_busy", (teachers, range(1, 51)), cat=LpBinary)
    previous_class = LpVariable.dicts("previous_class", (teachers, range(1, 51)), cat='Continuous')
    next_class = LpVariable.dicts("next_class", (teachers, range(1, 51)), cat='Continuous')
    double_classes_var = LpVariable.dicts("double_classes", (teachers, classes_opt, range(1, 50)), cat=LpBinary)
    triple_classes_var = LpVariable.dicts("triple_classes", (teachers, classes_opt, range(1, 49)), cat=LpBinary)

    # Problema de otimização
    prob = LpProblem("TeacherClassAssignment", LpMinimize)

    # Função objetivo (com múltiplos objetivos)
    prob += (
        lpSum(costs[(i, j, k)] * x_opt[i][j][k] for i in teachers for j in classes_opt for k in periods) 
        + double_classes_cost * lpSum(double_classes_var[i][j][k] for i in teachers for j in classes_opt for k in range(1, 50))
        + idle_periods_cost * lpSum(idle_periods_var[i][k] for i in teachers for k in periods)
        + triple_classes_cost * lpSum(triple_classes_var[i][j][k] for i in teachers for j in classes_opt for k in range(1, 49))
    )

    # Restrições
    # Disponibilidade dos professores
    for i in teachers:
        for k in periods:
            prob += (lpSum(x_opt[i][j][k] for j in classes_opt) + lpSum(valores_x_opt[(i, j, k)] for j in classes)) <= availability[(i, k)]

    # Cobertura das classes
    for j in classes_opt:
        for k in {1, 2, 3, 4, 5, 6, 11, 12, 13, 14, 15, 16, 21, 22, 23, 24, 25, 26, 31, 32, 33, 34, 35, 36, 41, 42, 43, 44, 45, 46}:
            prob += lpSum(x_opt[i][j][k] for i in teachers) == 1
        for k in {7, 8, 9, 10, 17, 18, 19, 20, 27, 28, 29, 30, 37, 38, 39, 40, 47, 48, 49, 50}:
            prob += lpSum(x_opt[i][j][k] for i in teachers) <= 1

    # Carga horária máx_optima
    for i in teachers:
        for j in classes_opt:
            prob += lpSum(x_opt[i][j][k] for k in periods) == teaching_load[i][j]

    # Sem sobreposição de classes
    for i in teachers:
        for k in periods:
            prob += (lpSum(x_opt[i][j][k] for j in classes_opt) + lpSum(valores_x_opt[(i, j, k)] for j in classes)) <= 1

   # Grupos de professores que não podem dar aula no mesmo período
    for group in ex_opt_groups:
        for k in periods:
            prob += (lpSum(x_opt[i][j][k] for i in group for j in classes_opt) + lpSum(valores_x_opt[(i, j, k)] for i in group for j in classes if (i, j, k) in valores_x_opt)) <= 1

    # Evitar mais de 3 aulas no período da manhã por dia
    for i in teachers:
        if i == 47:
            continue
        for j in classes_opt:
            for day_start in range(1, 50, 10):  # Itera pelos dias começando em 1, 11, 21, 31, 41
                prob += lpSum(x_opt[i][j][day_start + k] for k in range(6)) <= 2

    # Variável auxiliar para pares de períodos consecutivos na mesma turma
    edu_fisica_pair = LpVariable.dicts("edu_fisica_pair", (teachers, classes_opt, periods), cat=LpBinary)
    
    # Restrição para garantir que na classe Educação Física só hajam aulas duplas
    for i in [12, 37]:
        for j in classes_opt:
            for k in range(1, 49):  # Ajuste para evitar os períodos finais
                if k % 10 not in {7, 8, 9, 10}:  # Evita os períodos específicos
                    prob += edu_fisica_pair[i][j][k] <= x_opt[i][j][k]
                    prob += edu_fisica_pair[i][j][k] <= x_opt[i][j][k + 1]
                    prob += edu_fisica_pair[i][j][k] >= x_opt[i][j][k] + x[i][j][k + 1] - 1
                    # Assegura que a soma das variáveis auxiliares edu_fisica_pair é igual a 1, 
                    # ou seja, garantindo que os períodos k e k+1 sejam ambos alocados ou não alocados para educação física
    
    for i in [12, 37]:
        for j in classes_opt:
            prob += lpSum(edu_fisica_pair[i][j][k] for k in [1,2,3,4,5,11,12,13,14,15,21,22,23,24,25,31,32,33,34,35,41,42,43,44,45,]) == teaching_load[i][j] / 2
    
    # Evitar que aulas de educação física ocorram nos períodos proibidos
    for i in [12, 37]:
        for j in classes_opt:
            for k in [7, 8, 9, 10, 17, 18, 19, 20, 27, 28, 29, 30, 37, 38, 39, 40, 47, 48, 49, 50]:
                prob += x_opt[i][j][k] == 0

    
    for i in teachers:
        for k in range(1, 51):
            prob += nc[i][k] <= 1
            prob += pc[i][k] <= 1
            prob += ib[i][k] <= 1
            prob += z[i][k] <= 1
            prob += y[i][k] <= 1
            prob += idle_periods_var[i][k] <= 1
    
    for i in teachers:
        for day_start in range(1, 50, 10):
            for k in range(day_start + 1, day_start + 9):  # Evitando o primeiro período do dia
                # Definir se há aula no período atual
                prob += is_busy[i][k] == lpSum(x_opt[i][j][k] for j in classes_opt)
                prob += previous_class[i][k] == lpSum(x_opt[i][j][p] for j in classes_opt for p in range(day_start, k))
                prob += next_class[i][k] == lpSum(x_opt[i][j][p] for j in classes_opt for p in range(k + 1, day_start + 9))
    
                # Transformar as variáveis booleanas em binárias com limites superiores e inferiores
                prob += previous_class[i][k] <= M * pc[i][k]
                prob += previous_class[i][k] >= pc[i][k]
                prob += next_class[i][k] <= M * nc[i][k]
                prob += next_class[i][k] >= nc[i][k]
                prob += is_busy[i][k] <= M * ib[i][k]
                prob += is_busy[i][k] >= ib[i][k]
                prob += z[i][k] <= (pc[i][k] + (1 - is_busy[i][k])) / 2
                prob += z[i][k] >= (pc[i][k] + (1 - is_busy[i][k])) - 1
                prob += y[i][k] <= (z[i][k] + (nc[i][k])) / 2
                prob += y[i][k] >= (z[i][k] + (nc[i][k])) - 1
                prob += idle_periods_var[i][k] == y[i][k]
    # Restrições para contar double_classes
    for i in teachers:
        for j in classes_opt:
            for k in range(1, 50):
                prob += double_classes_var[i][j][k] >= x_opt[i][j][k] + x_opt[i][j][k + 1] - 1

    # Restrições para contar triple_classes
    for i in teachers:
        for j in classes_opt:
            for k in range(1, 49):
                prob += triple_classes_var[i][j][k] >= x_opt[i][j][k] + x_opt[i][j][k + 1] + x_opt[i][j][k + 2] - 2

    # Ex_optecução do solver com timeout
    solver = PULP_CBC_CMD(msg=True, timeLimit=timeout)  # Sem limite de tempo
    prob.solve(solver)

    # print("Status:", LpStatus[prob.status])
    # Atualizar valores das variáveis de decisão
    for i in teachers:
        for j in classes_opt:
            for k in range(1, 50):
                if x_opt[i][j][k].varValue is not None:
                    valores_x_opt[(i, j, k)] = x_opt[i][j][k].varValue 

    return valores_x_opt


def optimize_and_compare(all_classes, double_classes_cost, idle_periods_cost, triple_classes_cost, teachers, classesx2, classes_x2, periods, costs, valores_x0, availability, teaching_load, ex_groups, fo1):
    # Salvar os valores atuais
    current_values = {(i, j, k): x[i][j][k].varValue for i in teachers for j in all_classes for k in range(1, 50)}
    
    # Realizar a otimização
    valores_x1 = optimize_teacher_assignment(double_classes_cost, idle_periods_cost, triple_classes_cost, teachers, classesx2, classes_x2, periods, costs, valores_x0, availability, teaching_load, ex_groups)
    
    # Atualizar variáveis de decisão com os valores otimizados
    for i in teachers:
        for j in all_classes:
            for k in range(1, 50):
                x[i][j][k].varValue = valores_x1[(i, j, k)]
    improved_solution, _, _, _ = improve_solution(x, teachers, classes)
    # Atualizar variáveis de decisão com os valores otimizados
    for i in teachers:
        for j in all_classes:
            for k in range(1, 50):
                x[i][j][k].varValue = improved_solution[i][j][k].varValue
    # Avaliar a nova solução
    idle_periods, double_classes, triple_classes, fo2 = avaliar_solucao(x)
    
    # Mostrar o valor de FO na iteração atual
    print(f"FO anterior: {fo1}, FO atual: {fo2}")
    print("Idle Periods:", idle_periods)
    print("Double Classes:", double_classes)
    print("Triple Classes:", triple_classes)

    # Comparar a nova solução com a inicial e reverter se necessário
    if fo2 > fo1:
        # Restaurar os valores originais
        for (i, j, k) in current_values:
            x[i][j][k].varValue = current_values[(i, j, k)]
        print("Nova solução rejeitada.")
        return False, fo1, valores_x0  # Solução rejeitada
    else:
        fo1 = fo2  # Atualizar fo1 se a nova solução for melhor
        valores_x0 = valores_x1
        print("Nova solução aceita.")
        return True, fo1, valores_x0  # Solução aceita

# %% [markdown]
# Verifica se o problema relaxado tem solução

# %%
import pandas as pd
from pulp import LpProblem, LpMinimize, LpVariable, lpSum, LpBinary, LpStatus, value, PULP_CBC_CMD

tabela_prof = f'Horarios artificiais/horarios_embaralhado_linhas_1.csv'

# Carregar o arquivo CSV
dados = pd.read_csv(tabela_prof, sep=';', encoding='latin1')

def extract_availability(periods_str):
    if periods_str == '---------':
        return []
    available_periods = periods_str.split('-')
    return [int(p) for p in available_periods if p.isdigit()]

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
availability = {}
teachers = dados['No'].tolist()
periods = list(range(1, 51))  # 50 periods for each week

for i, row in dados.iterrows():
    teacher_id = row['No']
    for j, day in enumerate(days):
        day_period_start = j * 10 + 1
        available_periods = extract_availability(row[day])
        for period in range(1, 11):
            availability[(teacher_id, day_period_start + period - 1)] = 1 if period in available_periods else 0

# Definir as classes com base nas colunas do CSV
classes = ['6oA', '6oB', '7oA', '7oB', '8oA', '8oB','9oA', '9oB', '1oA', '1oB','2oA', '2oB', '3o']

# Modificar para gerar o t[i, j]
teaching_load = {}

# Verificar se as colunas de carga máxima existem no CSV
missing_columns = [col for col in classes if col not in dados.columns]

if missing_columns:
    raise KeyError(f"Missing columns in CSV: {', '.join(missing_columns)}")

# Carga horária em cada classe de cada professor
for i, row in dados.iterrows():
    teacher_id = row['No']
    teaching_load[teacher_id] = {}
    for cls in classes:
        teaching_load[teacher_id][cls] = row[cls]

# Definir os custos
costs = {}
for i, row in dados.iterrows():
    teacher_id = row['No']
    for cls in classes:
        for day in range(5):
            for period in range(1, 11):
                actual_period = day * 10 + period
                cost = 1 if period <= 6 else 1000 if period == 7 else 5000 if period == 8 else 10000 if period == 9 else 40000
                costs[(teacher_id, cls, actual_period)] = cost

# Variáveis de decisão
x = LpVariable.dicts("x", (teachers, classes, periods), cat=LpBinary)

# Problema de otimização
prob = LpProblem("TeacherClassAssignment", LpMinimize)

# Função objetivo
prob += lpSum(costs[(i, j, k)] * x[i][j][k] for i in teachers for j in classes for k in periods)

# Restrições

# Disponibilidade dos professores
for i in teachers:
    for k in periods:
        prob += lpSum(x[i][j][k] for j in classes) <= availability[(i, k)]

# Cobertura das classes
for j in classes:
    for k in {1,2,3,4,5,6,11,12,13,14,15,16,21,22,23,24,25,26,31,32,33,34,35,36,41,42,43,44,45,46}:
        prob += lpSum(x[i][j][k] for i in teachers) == 1
    for k in {7,8,9,10,17,18,19,20,27,28,29,30,37,38,39,40,47,48,49,50}:
        prob += lpSum(x[i][j][k] for i in teachers) <= 1

# Carga horária máxima
for i in teachers:
    for j in classes:
        prob += lpSum(x[i][j][k] for k in periods) == teaching_load[i][j]

# Sem sobreposição de classes
for i in teachers:
    for k in periods:
        prob += lpSum(x[i][j][k] for j in classes) <= 1

# Grupos de professores que não podem dar aula no mesmo período
exclusive_groups = [
    #[4, 44],
    [45, 22, 25],
    [46, 38, 31],
    [32, 33]
]


for group in exclusive_groups:
    for k in periods:
        prob += lpSum(x[i][j][k] for i in group for j in classes) <= 1

# Evitar mais de 3 aulas no período da manhã por dia
for i in teachers:
    if i == 47:
        continue
    for j in classes:
        for day_start in range(1, 50, 10):  # Itera pelos dias começando em 1, 11, 21, 31, 41
            prob += lpSum(x[i][j][day_start + k] for k in range(6)) <= 2

# Conjunto dos períodos a serem evitados para educação física
periods_to_avoid = {7, 8, 9, 10, 17, 18, 19, 20, 27, 28, 29, 30, 37, 38, 39, 40, 47, 48, 49, 50}

# Variável auxiliar para pares de períodos consecutivos na mesma turma
edu_fisica_pair = LpVariable.dicts("edu_fisica_pair", (teachers, classes, periods), cat=LpBinary)

# Restrição para garantir que na classe Educação Física só hajam aulas duplas
for i in [12, 37]:
    for j in classes:
        for k in range(1, 49):  # Ajuste para evitar os períodos finais
            if k % 10 not in {7, 8, 9, 10}:  # Evita os períodos específicos
                prob += edu_fisica_pair[i][j][k] <= x[i][j][k]
                prob += edu_fisica_pair[i][j][k] <= x[i][j][k + 1]
                prob += edu_fisica_pair[i][j][k] >= x[i][j][k] + x[i][j][k + 1] - 1
                # Assegura que a soma das variáveis auxiliares edu_fisica_pair é igual a 1, 
                # ou seja, garantindo que os períodos k e k+1 sejam ambos alocados ou não alocados para educação física

for i in [12, 37]:
    for j in classes:
        prob += lpSum(edu_fisica_pair[i][j][k] for k in [1,2,3,4,5,11,12,13,14,15,21,22,23,24,25,31,32,33,34,35,41,42,43,44,45,]) == teaching_load[i][j] / 2

# Evitar que aulas de educação física ocorram nos períodos proibidos
for i in [12, 37]:
    for j in classes:
        for k in [7, 8, 9, 10, 17, 18, 19, 20, 27, 28, 29, 30, 37, 38, 39, 40, 47, 48, 49, 50]:
            prob += x[i][j][k] == 0

# for i in [12,37]:
#     for j in classes:
#         for k in range(1, 50, 2):  # Itere apenas sobre os períodos ímpares para garantir a continuidade
#             prob += x[i][j][k] == x[i][j][k + 1]

# # # # Restrição para garantir que na classe '3o' só hajam aulas duplas
# for i in teachers:
#     for k in range(1, 50, 2):  # Itere apenas sobre os períodos ímpares para garantir a continuidade
#         prob += x[i]['3o'][k] == x[i]['3o'][k + 1]

# Execução do solver com timeout
#solver = PULP_CBC_CMD(timeLimit=30, msg=True)  # 'timeLimit' define o tempo máximo
solver = PULP_CBC_CMD(msg=True)  # Sem limite de tempo
prob.solve(solver)

print("Status:", LpStatus[prob.status])

# Criar um dicionário para armazenar os valores das variáveis de decisão
valores_x = {}

# Iterar sobre as combinações de professores, disciplinas e períodos
for i in teachers:
    for j in ['6oA', '6oB', '7oA', '7oB','8oA', '8oB','9oA', '9oB', '1oA', '1oB', '2oA', '2oB', '3o']:
        for k in range(1, 51):
            # Verificar se a variável de decisão está definida e obter o valor
            if x[i][j][k].varValue is not None:
                valores_x[(i, j, k)] = x[i][j][k].varValue
# Out:
# Status: Optimal

# %%
# Avalia a solução inicial
idle_periods_ORIGINAL, double_classes_ORIGINAL, triple_classes_ORIGINAL, fo_ORIGINAL = avaliar_solucao(x)
print("Idle Periods:", idle_periods_ORIGINAL)
print("Double Classes:", double_classes_ORIGINAL)
print("Triple Classes:", triple_classes_ORIGINAL)
print("Triple Classes:", fo_ORIGINAL)
# Out:
# Idle Periods: 80
# Double Classes: 44
# Triple Classes: 2
# Triple Classes: 68000

# %%
# Gera um excel colorido da versão inicial
generate_and_export_timetable(teachers, classes, periods, x, dados, 'timetable_colored_0.xlsx')
# Out:
# Arquivo Excel salvo como timetable_colored_0.xlsx

# %%
# Fix and Optimize Heuristic
# Inicializar variáveis
import time
# Iniciar a contagem de tempo
start_time = time.time()

# Inicializar variáveis
valores_x0 = valores_x
idle_periods, double_classes, triple_classes, fo1 = avaliar_solucao(x)
print("fo1:", fo1)

# Definir todas as turmas
all_classes = ['6oA', '6oB', '7oA', '7oB', '8oA', '8oB', '9oA', '9oB', '1oA', '1oB', '2oA', '2oB', '3o']

double_classes_cost = -500
idle_periods_cost = 1000
triple_classes_cost = 5000

# Iterar até 20 iterações ou até todas as soluções serem rejeitadas
max_iterations = 20
iteration = 0
all_rejected = False

while iteration < max_iterations and not all_rejected:
    iteration += 1
    all_rejected = True  # Suponha que todas as soluções serão rejeitadas nesta iteração
    print(f"\nIteração {iteration}:")

    for i in range(0, len(all_classes), 2):
        classesx2 = all_classes[i:i+2]
        classes_x2 = [cls for cls in all_classes if cls not in classesx2]
        ex_groups = [[45, 22, 25], [46, 38, 31], [32, 33]]
        print(f"Otimizando para turmas: {classesx2}")
        accepted, fo1, valores_x0 = optimize_and_compare(all_classes,double_classes_cost,idle_periods_cost,triple_classes_cost,teachers, classesx2, classes_x2, periods, costs, valores_x0, availability, teaching_load, ex_groups, fo1)
        if accepted:
            all_rejected = False  # Se alguma solução foi aceita, não interrompa ainda

    if all_rejected:
        print(f"Ponto ótimo alcançado em {iteration} iterações.")
        break

if iteration == max_iterations:
    print("Número limite de iterações atingido.")

improved_solution, new_idle_periods, new_double_classes, new_triple_classes = improve_solution(x, teachers, classes)

# Parar a contagem de tempo
end_time = time.time()

# Calcular o tempo total de execução
total_time = end_time - start_time
print(f"Tempo total de execução: {total_time} segundos")
# Out:
# fo1: 68000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 68000, FO atual: 68500
# Idle Periods: 82
# Double Classes: 47
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 68000, FO atual: 66000
# Idle Periods: 80
# Double Classes: 48
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 66000, FO atual: 56500
# Idle Periods: 74
# Double Classes: 55
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 56500, FO atual: 58000
# Idle Periods: 76
# Double Classes: 56
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 56500, FO atual: 50000
# Idle Periods: 68
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 50000, FO atual: 47000
# Idle Periods: 67
# Double Classes: 60
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 47000, FO atual: 46500
# Idle Periods: 66
# Double Classes: 59
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 46500, FO atual: 44500
# Idle Periods: 65
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 44500, FO atual: 47000
# Idle Periods: 66
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 44500, FO atual: 58000
# Idle Periods: 74
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 44500, FO atual: 67000
# Idle Periods: 82
# Double Classes: 50
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 44500, FO atual: 63000
# Idle Periods: 79
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 44500, FO atual: 63500
# Idle Periods: 79
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 44500, FO atual: 62000
# Idle Periods: 78
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 44500, FO atual: 62000
# Idle Periods: 78
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 44500, FO atual: 60500
# Idle Periods: 78
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 44500, FO atual: 49000
# Idle Periods: 68
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 44500, FO atual: 40500
# Idle Periods: 62
# Double Classes: 63
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 40500, FO atual: 38500
# Idle Periods: 58
# Double Classes: 59
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 38500, FO atual: 36500
# Idle Periods: 56
# Double Classes: 59
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 36500, FO atual: 40500
# Idle Periods: 59
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 4:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 36500, FO atual: 42500
# Idle Periods: 60
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 36500, FO atual: 42000
# Idle Periods: 59
# Double Classes: 54
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 36500, FO atual: 44000
# Idle Periods: 60
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 36500, FO atual: 52000
# Idle Periods: 65
# Double Classes: 46
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 36500, FO atual: 51500
# Idle Periods: 65
# Double Classes: 47
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 36500, FO atual: 52500
# Idle Periods: 66
# Double Classes: 47
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 36500, FO atual: 50500
# Idle Periods: 65
# Double Classes: 49
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 4 iterações.
# Tempo total de execução: 226.54882740974426 segundos

# %%
# Avalia a solução final
idle_periods, double_classes, triple_classes, fo = avaliar_solucao(improved_solution)
print("Idle Periods:", idle_periods)
print("Double Classes:", double_classes)
print("Triple Classes:", triple_classes)
print("FO:", fo)

improved_solution, new_idle_periods, new_double_classes, new_triple_classes = improve_solution(x, teachers, classes)
# Out:
# Idle Periods: 56
# Double Classes: 59
# Triple Classes: 2
# FO: 36500

# %%
# Gera a grade de horários colorida
generate_and_export_timetable(teachers, classes, periods, improved_solution, dados, 'timetable_coloredFO_final.xlsx')
# Out:
# Arquivo Excel salvo como timetable_coloredFO_final.xlsx

# %% [markdown]
# Medição de dados

# %%
import time
import pandas as pd
# Listas para armazenar os resultados
total_time = []
media_tempo_iteracao = []
antes_idle_periods = []
antes_double_classes = []
antes_triple_classes = []
antes_fo = []
depois_idle_periods = []
depois_double_classes = []
depois_triple_classes = []
depois_fo = []
iterations = []  # Lista para armazenar o número da iteração
optimalmsg =[]
start_time_ALLPROGRAM = time.time()
for n in range(1, 101):
    print(n)
    # Iniciar contagem de tempo total
    start_time_total = time.time()
    tabela_prof = f'Horarios artificiais/horarios_embaralhado_linhas_{n}.csv'
    # tabela_prof = 'tabela_profDados.csv'
    
    import pandas as pd
    from pulp import LpProblem, LpMinimize, LpVariable, lpSum, LpBinary, LpStatus, value, PULP_CBC_CMD
    
    
    
    # Carregar o arquivo CSV
    dados = pd.read_csv(tabela_prof, sep=';', encoding='latin1')
    
    def extract_availability(periods_str):
        if periods_str == '---------':
            return []
        available_periods = periods_str.split('-')
        return [int(p) for p in available_periods if p.isdigit()]
    
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
    availability = {}
    teachers = dados['No'].tolist()
    periods = list(range(1, 51))  # 50 periods for each week
    
    for i, row in dados.iterrows():
        teacher_id = row['No']
        for j, day in enumerate(days):
            day_period_start = j * 10 + 1
            available_periods = extract_availability(row[day])
            for period in range(1, 11):
                availability[(teacher_id, day_period_start + period - 1)] = 1 if period in available_periods else 0
    
    # Definir as classes com base nas colunas do CSV
    classes = ['6oA', '6oB', '7oA', '7oB', '8oA', '8oB','9oA', '9oB', '1oA', '1oB','2oA', '2oB', '3o']
    
    # Modificar para gerar o t[i, j]
    teaching_load = {}
    
    # Verificar se as colunas de carga máxima existem no CSV
    missing_columns = [col for col in classes if col not in dados.columns]
    
    if missing_columns:
        raise KeyError(f"Missing columns in CSV: {', '.join(missing_columns)}")
    
    # Carga horária em cada classe de cada professor
    for i, row in dados.iterrows():
        teacher_id = row['No']
        teaching_load[teacher_id] = {}
        for cls in classes:
            teaching_load[teacher_id][cls] = row[cls]
    
    # Definir os custos
    costs = {}
    for i, row in dados.iterrows():
        teacher_id = row['No']
        for cls in classes:
            for day in range(5):
                for period in range(1, 11):
                    actual_period = day * 10 + period
                    cost = 1 if period <= 6 else 1000 if period == 7 else 5000 if period == 8 else 10000 if period == 9 else 40000
                    costs[(teacher_id, cls, actual_period)] = cost
    
    # Variáveis de decisão
    x = LpVariable.dicts("x", (teachers, classes, periods), cat=LpBinary)
    
    # Problema de otimização
    prob = LpProblem("TeacherClassAssignment", LpMinimize)
    
    # Função objetivo
    prob += lpSum(costs[(i, j, k)] * x[i][j][k] for i in teachers for j in classes for k in periods)
    
    # Restrições
    
    # Disponibilidade dos professores
    for i in teachers:
        for k in periods:
            prob += lpSum(x[i][j][k] for j in classes) <= availability[(i, k)]
    
    # Cobertura das classes
    for j in classes:
        for k in {1,2,3,4,5,6,11,12,13,14,15,16,21,22,23,24,25,26,31,32,33,34,35,36,41,42,43,44,45,46}:
            prob += lpSum(x[i][j][k] for i in teachers) == 1
        for k in {7,8,9,10,17,18,19,20,27,28,29,30,37,38,39,40,47,48,49,50}:
            prob += lpSum(x[i][j][k] for i in teachers) <= 1
    
    # Carga horária máxima
    for i in teachers:
        for j in classes:
            prob += lpSum(x[i][j][k] for k in periods) == teaching_load[i][j]
    
    # Sem sobreposição de classes
    for i in teachers:
        for k in periods:
            prob += lpSum(x[i][j][k] for j in classes) <= 1
    
    # Grupos de professores que não podem dar aula no mesmo período
    exclusive_groups = [
        #[4, 44],
        [45, 22, 25],
        [46, 38, 31],
        [32, 33]
    ]
    
    
    for group in exclusive_groups:
        for k in periods:
            prob += lpSum(x[i][j][k] for i in group for j in classes) <= 1
    
    # Evitar mais de 3 aulas no período da manhã por dia
    for i in teachers:
        if i == 47:
            continue
        for j in classes:
            for day_start in range(1, 50, 10):  # Itera pelos dias começando em 1, 11, 21, 31, 41
                prob += lpSum(x[i][j][day_start + k] for k in range(6)) <= 2
    
    # Conjunto dos períodos a serem evitados para educação física
    periods_to_avoid = {7, 8, 9, 10, 17, 18, 19, 20, 27, 28, 29, 30, 37, 38, 39, 40, 47, 48, 49, 50}
    
    # Variável auxiliar para pares de períodos consecutivos na mesma turma
    edu_fisica_pair = LpVariable.dicts("edu_fisica_pair", (teachers, classes, periods), cat=LpBinary)
    
    # Restrição para garantir que na classe Educação Física só hajam aulas duplas
    for i in [12, 37]:
        for j in classes:
            for k in range(1, 49):  # Ajuste para evitar os períodos finais
                if k % 10 not in {7, 8, 9, 10}:  # Evita os períodos específicos
                    prob += edu_fisica_pair[i][j][k] <= x[i][j][k]
                    prob += edu_fisica_pair[i][j][k] <= x[i][j][k + 1]
                    prob += edu_fisica_pair[i][j][k] >= x[i][j][k] + x[i][j][k + 1] - 1
                    # Assegura que a soma das variáveis auxiliares edu_fisica_pair é igual a 1, 
                    # ou seja, garantindo que os períodos k e k+1 sejam ambos alocados ou não alocados para educação física
    
    for i in [12, 37]:
        for j in classes:
            prob += lpSum(edu_fisica_pair[i][j][k] for k in [1,2,3,4,5,11,12,13,14,15,21,22,23,24,25,31,32,33,34,35,41,42,43,44,45,]) == teaching_load[i][j] / 2
    
    # Evitar que aulas de educação física ocorram nos períodos proibidos
    for i in [12, 37]:
        for j in classes:
            for k in [7, 8, 9, 10, 17, 18, 19, 20, 27, 28, 29, 30, 37, 38, 39, 40, 47, 48, 49, 50]:
                prob += x[i][j][k] == 0
    
    # for i in [12,37]:
    #     for j in classes:
    #         for k in range(1, 50, 2):  # Itere apenas sobre os períodos ímpares para garantir a continuidade
    #             prob += x[i][j][k] == x[i][j][k + 1]
    
    # # # # Restrição para garantir que na classe '3o' só hajam aulas duplas
    # for i in teachers:
    #     for k in range(1, 50, 2):  # Itere apenas sobre os períodos ímpares para garantir a continuidade
    #         prob += x[i]['3o'][k] == x[i]['3o'][k + 1]
    
    # Execução do solver com timeout
    #solver = PULP_CBC_CMD(timeLimit=30, msg=True)  # 'timeLimit' define o tempo máximo
    solver = PULP_CBC_CMD(msg=True)  # Sem limite de tempo
    prob.solve(solver)
    optimalmsg.append(LpStatus[prob.status])
    # Criar um dicionário para armazenar os valores das variáveis de decisão
    valores_x = {}
    
    # Iterar sobre as combinações de professores, disciplinas e períodos
    for i in teachers:
        for j in ['6oA', '6oB', '7oA', '7oB','8oA', '8oB','9oA', '9oB', '1oA', '1oB', '2oA', '2oB', '3o']:
            for k in range(1, 51):
                # Verificar se a variável de decisão está definida e obter o valor
                if x[i][j][k].varValue is not None:
                    valores_x[(i, j, k)] = x[i][j][k].varValue

    
    # Inicializar variáveis
    valores_x0 = valores_x
    
    # Definir todas as turmas
    all_classes = ['6oA', '6oB', '7oA', '7oB', '8oA', '8oB', '9oA', '9oB', '1oA', '1oB', '2oA', '2oB', '3o']
    
    double_classes_cost = -500
    idle_periods_cost = 1000
    triple_classes_cost = 5000
    
    ex_groups = [[45, 22, 25], [46, 38, 31], [32, 33]]
    
    # Registrar estado antes da heurística
    idle_periods, double_classes, triple_classes, fo1 = avaliar_solucao(x)
    antes_idle_periods.append(idle_periods)
    antes_double_classes.append(double_classes)
    antes_triple_classes.append(triple_classes)
    antes_fo.append(fo1)
    

    print("fo1:", fo1)
    
    # Iterar até 20 iterações ou até todas as soluções serem rejeitadas
    max_iterations = 20
    iteration = 0
    all_rejected = False
    
    # Lista para armazenar tempos de cada iteração
    tempos_iteracoes = []
    
    while iteration < max_iterations and not all_rejected:
        iteration += 1
        all_rejected = True  # Suponha que todas as soluções serão rejeitadas nesta iteração
        print(f"\nIteração {iteration}:")
    
        for i in range(0, len(all_classes), 2):
            classesx2 = all_classes[i:i+2]
            classes_x2 = [cls for cls in all_classes if cls not in classesx2]
            print(f"Otimizando para turmas: {classesx2}")
    
            # Iniciar contagem de tempo para a iteração
            start_time_iter = time.time()
    
            accepted, fo1, valores_x0 = optimize_and_compare(all_classes, double_classes_cost, idle_periods_cost,
                                                             triple_classes_cost, teachers, classesx2, classes_x2,
                                                             periods, costs, valores_x0, availability,
                                                             teaching_load, ex_groups, fo1)
    
            # Finalizar contagem de tempo para a iteração
            end_time_iter = time.time()
            tempo_iteracao = end_time_iter - start_time_iter
            tempos_iteracoes.append(tempo_iteracao)
    
            if accepted:
                all_rejected = False  # Se alguma solução foi aceita, não interrompa ainda

        if all_rejected:
            print(f"Ponto ótimo alcançado em {iteration} iterações.")
            break
    
    if iteration == max_iterations:
        print("Número limite de iterações atingido.")
    
    # Registrar estado depois das iterações
    idle_periods, double_classes, triple_classes, fo1 = avaliar_solucao(x)
    depois_idle_periods.append(idle_periods)
    depois_double_classes.append(double_classes)
    depois_triple_classes.append(triple_classes)
    depois_fo.append(fo1)
    
    # Calcular o tempo total de execução
    end_time_total = time.time()
    total_time.append(end_time_total - start_time_total)
    media_tempo_iteracao.append(sum(tempos_iteracoes) / len(tempos_iteracoes) if tempos_iteracoes else 0)
    iterations.append(iteration)  # Armazenar o valor de iteration


# DataFrame com todos os dados coletados
data = {
    'Optimal': optimalmsg,
    'Iteration':iterations,
    'Total time (seconds)': total_time,
    'Average Iteration Time (seconds)': media_tempo_iteracao,
    'Idle Periods Before': antes_idle_periods,
    'Idle Periods After': depois_idle_periods,
    'Double Classes After': depois_double_classes,
    'Double Classes Before': antes_double_classes,
    'Triple Classes Before': antes_triple_classes,
    'Triple Classes After': depois_triple_classes,
    'Objective Function Before': antes_fo,
    'Objective Function After': depois_fo
}
# Criar o DataFrame
df = pd.DataFrame(data)

# Calcular as melhorias
df['Idle Periods Improvement'] = (1 - (df['Idle Periods After'] / df['Idle Periods Before'])) * 100
df['Double Classes Improvement'] = ((df['Double Classes After'] / df['Double Classes Before']) - 1) * 100
df['Triple Classes Improvement'] = (1 - (df['Triple Classes After'] / df['Triple Classes Before'])) * 100
df['Objective Function Improvement'] = (1-(df['Objective Function After'] / df['Objective Function Before']) ) * 100

# Formatar as melhorias com duas casas decimais e o símbolo de porcentagem
df['Idle Periods Improvement'] = df['Idle Periods Improvement'].apply(lambda x: f"{x:.2f}%")
df['Double Classes Improvement'] = df['Double Classes Improvement'].apply(lambda x: f"{x:.2f}%")
df['Triple Classes Improvement'] = df['Triple Classes Improvement'].apply(lambda x: f"{x:.2f}%")
df['Objective Function Improvement'] = df['Objective Function Improvement'].apply(lambda x: f"{x:.2f}%")

# Remover colunas indesejadas
df = df[['Optimal','Iteration', 'Total time (seconds)', 'Average Iteration Time (seconds)', 
         'Idle Periods Before', 'Idle Periods After', 'Idle Periods Improvement',
         'Double Classes Before', 'Double Classes After', 'Double Classes Improvement',
         'Triple Classes Before', 'Triple Classes After', 'Triple Classes Improvement',
         'Objective Function Before', 'Objective Function After', 'Objective Function Improvement']]

# Nome do arquivo de saída
# output = f"Dados_sobre_tabela_artifical{n+2}.xlsx"
output = f"Dados_sobre_tabela_real_Consertado{n+6}.xlsx"
# # Criar DataFrame
# df = pd.DataFrame(data)
# Salvar o DataFrame em um arquivo Excel
df.to_excel(output, index=False)

# Calcular o tempo total de execução
end_timeTotal = time.time()
total_time = end_timeTotal - start_time_ALLPROGRAM
print(f"Tempo total de execução: {total_time} segundos")
# Out:
# 1
# fo1: 68000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 68000, FO atual: 68500
# Idle Periods: 82
# Double Classes: 47
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 68000, FO atual: 66000
# Idle Periods: 80
# Double Classes: 48
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 66000, FO atual: 56500
# Idle Periods: 74
# Double Classes: 55
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 56500, FO atual: 58000
# Idle Periods: 76
# Double Classes: 56
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 56500, FO atual: 50000
# Idle Periods: 68
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 50000, FO atual: 47000
# Idle Periods: 67
# Double Classes: 60
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 47000, FO atual: 46500
# Idle Periods: 66
# Double Classes: 59
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 46500, FO atual: 44500
# Idle Periods: 65
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 44500, FO atual: 47000
# Idle Periods: 66
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 44500, FO atual: 58000
# Idle Periods: 74
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 44500, FO atual: 67000
# Idle Periods: 82
# Double Classes: 50
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 44500, FO atual: 63000
# Idle Periods: 79
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 44500, FO atual: 63500
# Idle Periods: 79
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 44500, FO atual: 62000
# Idle Periods: 78
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 44500, FO atual: 62000
# Idle Periods: 78
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 44500, FO atual: 60500
# Idle Periods: 78
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 44500, FO atual: 49000
# Idle Periods: 68
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 44500, FO atual: 40500
# Idle Periods: 62
# Double Classes: 63
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 40500, FO atual: 38500
# Idle Periods: 58
# Double Classes: 59
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 38500, FO atual: 36500
# Idle Periods: 56
# Double Classes: 59
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 36500, FO atual: 40500
# Idle Periods: 59
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 4:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 36500, FO atual: 42500
# Idle Periods: 60
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 36500, FO atual: 42000
# Idle Periods: 59
# Double Classes: 54
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 36500, FO atual: 44000
# Idle Periods: 60
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 36500, FO atual: 52000
# Idle Periods: 65
# Double Classes: 46
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 36500, FO atual: 51500
# Idle Periods: 65
# Double Classes: 47
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 36500, FO atual: 52500
# Idle Periods: 66
# Double Classes: 47
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 36500, FO atual: 50500
# Idle Periods: 65
# Double Classes: 49
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 4 iterações.
# 2
# fo1: 75500
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 75500, FO atual: 72000
# Idle Periods: 83
# Double Classes: 42
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 72000, FO atual: 71500
# Idle Periods: 83
# Double Classes: 43
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 71500, FO atual: 62000
# Idle Periods: 74
# Double Classes: 44
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 62000, FO atual: 49000
# Idle Periods: 62
# Double Classes: 46
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 49000, FO atual: 42500
# Idle Periods: 56
# Double Classes: 47
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 42500, FO atual: 36500
# Idle Periods: 50
# Double Classes: 47
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 36500, FO atual: 33500
# Idle Periods: 48
# Double Classes: 49
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 33500, FO atual: 31500
# Idle Periods: 47
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 31500, FO atual: 29000
# Idle Periods: 47
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 29000, FO atual: 29500
# Idle Periods: 49
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 29000, FO atual: 28500
# Idle Periods: 49
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 28500, FO atual: 25500
# Idle Periods: 46
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 25500, FO atual: 27000
# Idle Periods: 48
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 25500, FO atual: 28500
# Idle Periods: 49
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 25500, FO atual: 26500
# Idle Periods: 47
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 25500, FO atual: 28000
# Idle Periods: 48
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 25500, FO atual: 30000
# Idle Periods: 50
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 25500, FO atual: 31500
# Idle Periods: 52
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 25500, FO atual: 28000
# Idle Periods: 50
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 25500, FO atual: 23000
# Idle Periods: 46
# Double Classes: 66
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 23000, FO atual: 21500
# Idle Periods: 45
# Double Classes: 67
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 4:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 21500, FO atual: 22000
# Idle Periods: 45
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 21500, FO atual: 28000
# Idle Periods: 50
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 21500, FO atual: 23000
# Idle Periods: 46
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 21500, FO atual: 19000
# Idle Periods: 41
# Double Classes: 64
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 19000, FO atual: 14000
# Idle Periods: 37
# Double Classes: 66
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 14000, FO atual: 16000
# Idle Periods: 38
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 14000, FO atual: 12500
# Idle Periods: 34
# Double Classes: 63
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 5:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 12500, FO atual: 14500
# Idle Periods: 35
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 12500, FO atual: 15500
# Idle Periods: 38
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 12500, FO atual: 25500
# Idle Periods: 48
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 12500, FO atual: 30000
# Idle Periods: 51
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 12500, FO atual: 38000
# Idle Periods: 57
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 12500, FO atual: 39000
# Idle Periods: 59
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 12500, FO atual: 38500
# Idle Periods: 59
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 5 iterações.
# 3
# fo1: 60000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 60000, FO atual: 54500
# Idle Periods: 70
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 54500, FO atual: 44000
# Idle Periods: 60
# Double Classes: 52
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 44000, FO atual: 42500
# Idle Periods: 59
# Double Classes: 53
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 42500, FO atual: 37500
# Idle Periods: 53
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 37500, FO atual: 31000
# Idle Periods: 49
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 31000, FO atual: 29500
# Idle Periods: 50
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 29500, FO atual: 32500
# Idle Periods: 53
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 29500, FO atual: 34000
# Idle Periods: 55
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 29500, FO atual: 42500
# Idle Periods: 63
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 29500, FO atual: 38000
# Idle Periods: 59
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 29500, FO atual: 44500
# Idle Periods: 65
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 29500, FO atual: 35000
# Idle Periods: 54
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 29500, FO atual: 37500
# Idle Periods: 56
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 29500, FO atual: 37000
# Idle Periods: 56
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 2 iterações.
# 4
# fo1: 76500
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 76500, FO atual: 71500
# Idle Periods: 85
# Double Classes: 47
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 71500, FO atual: 63500
# Idle Periods: 79
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 63500, FO atual: 45000
# Idle Periods: 61
# Double Classes: 52
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 45000, FO atual: 40500
# Idle Periods: 57
# Double Classes: 53
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 40500, FO atual: 49000
# Idle Periods: 64
# Double Classes: 50
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 40500, FO atual: 45500
# Idle Periods: 61
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 40500, FO atual: 42000
# Idle Periods: 59
# Double Classes: 54
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 40500, FO atual: 41500
# Idle Periods: 56
# Double Classes: 49
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 40500, FO atual: 35000
# Idle Periods: 49
# Double Classes: 48
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 35000, FO atual: 45500
# Idle Periods: 61
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 35000, FO atual: 44500
# Idle Periods: 60
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 35000, FO atual: 50500
# Idle Periods: 68
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 35000, FO atual: 58500
# Idle Periods: 77
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 35000, FO atual: 55500
# Idle Periods: 74
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 35000, FO atual: 52000
# Idle Periods: 72
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 35000, FO atual: 51000
# Idle Periods: 72
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 35000, FO atual: 43000
# Idle Periods: 65
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 35000, FO atual: 42500
# Idle Periods: 64
# Double Classes: 63
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 35000, FO atual: 34500
# Idle Periods: 55
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 34500, FO atual: 35000
# Idle Periods: 56
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 34500, FO atual: 31500
# Idle Periods: 52
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 4:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 31500, FO atual: 29000
# Idle Periods: 50
# Double Classes: 62
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 29000, FO atual: 31500
# Idle Periods: 51
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 29000, FO atual: 28500
# Idle Periods: 49
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 28500, FO atual: 24000
# Idle Periods: 45
# Double Classes: 62
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 24000, FO atual: 13500
# Idle Periods: 37
# Double Classes: 67
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 13500, FO atual: 22000
# Idle Periods: 44
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 13500, FO atual: 20000
# Idle Periods: 43
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 5:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 13500, FO atual: 22500
# Idle Periods: 45
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 13500, FO atual: 23000
# Idle Periods: 47
# Double Classes: 68
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 13500, FO atual: 23500
# Idle Periods: 47
# Double Classes: 67
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 13500, FO atual: 29500
# Idle Periods: 52
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 13500, FO atual: 22000
# Idle Periods: 44
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 13500, FO atual: 29000
# Idle Periods: 51
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 13500, FO atual: 32000
# Idle Periods: 54
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 5 iterações.
# 5
# fo1: 36500
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 36500, FO atual: 27500
# Idle Periods: 28
# Double Classes: 1
# Triple Classes: 0
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 27500, FO atual: 21500
# Idle Periods: 22
# Double Classes: 1
# Triple Classes: 0
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 21500, FO atual: 17500
# Idle Periods: 18
# Double Classes: 1
# Triple Classes: 0
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 17500, FO atual: 13500
# Idle Periods: 14
# Double Classes: 1
# Triple Classes: 0
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 13500, FO atual: 12500
# Idle Periods: 13
# Double Classes: 1
# Triple Classes: 0
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 12500, FO atual: 10500
# Idle Periods: 11
# Double Classes: 1
# Triple Classes: 0
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 10500, FO atual: 13000
# Idle Periods: 14
# Double Classes: 2
# Triple Classes: 0
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 10500, FO atual: 30000
# Idle Periods: 31
# Double Classes: 2
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 10500, FO atual: 34500
# Idle Periods: 36
# Double Classes: 3
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 10500, FO atual: 41500
# Idle Periods: 44
# Double Classes: 5
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 10500, FO atual: 44500
# Idle Periods: 47
# Double Classes: 5
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 10500, FO atual: 44500
# Idle Periods: 47
# Double Classes: 5
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 10500, FO atual: 35500
# Idle Periods: 38
# Double Classes: 5
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 10500, FO atual: 28000
# Idle Periods: 30
# Double Classes: 4
# Triple Classes: 0
# Nova solução rejeitada.
# Ponto ótimo alcançado em 2 iterações.
# 6
# fo1: 69000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 69000, FO atual: 67500
# Idle Periods: 74
# Double Classes: 33
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 67500, FO atual: 64500
# Idle Periods: 72
# Double Classes: 35
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 64500, FO atual: 52000
# Idle Periods: 60
# Double Classes: 36
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 52000, FO atual: 50500
# Idle Periods: 61
# Double Classes: 41
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 50500, FO atual: 41500
# Idle Periods: 54
# Double Classes: 45
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 41500, FO atual: 40500
# Idle Periods: 55
# Double Classes: 49
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 40500, FO atual: 36500
# Idle Periods: 53
# Double Classes: 53
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 36500, FO atual: 30000
# Idle Periods: 48
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 30000, FO atual: 30500
# Idle Periods: 46
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 30000, FO atual: 33500
# Idle Periods: 49
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 30000, FO atual: 27000
# Idle Periods: 41
# Double Classes: 48
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 27000, FO atual: 28500
# Idle Periods: 43
# Double Classes: 49
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 27000, FO atual: 26500
# Idle Periods: 42
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 26500, FO atual: 32000
# Idle Periods: 46
# Double Classes: 48
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 26500, FO atual: 33000
# Idle Periods: 45
# Double Classes: 44
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 26500, FO atual: 31000
# Idle Periods: 45
# Double Classes: 48
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 26500, FO atual: 29500
# Idle Periods: 44
# Double Classes: 49
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 26500, FO atual: 37000
# Idle Periods: 53
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 26500, FO atual: 37000
# Idle Periods: 52
# Double Classes: 50
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 26500, FO atual: 32500
# Idle Periods: 47
# Double Classes: 49
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 26500, FO atual: 31500
# Idle Periods: 46
# Double Classes: 49
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 3 iterações.
# 7
# fo1: 46500
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 46500, FO atual: 46500
# Idle Periods: 52
# Double Classes: 41
# Triple Classes: 3
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 46500, FO atual: 44500
# Idle Periods: 50
# Double Classes: 41
# Triple Classes: 3
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 44500, FO atual: 39500
# Idle Periods: 47
# Double Classes: 45
# Triple Classes: 3
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 39500, FO atual: 28000
# Idle Periods: 37
# Double Classes: 48
# Triple Classes: 3
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 28000, FO atual: 21500
# Idle Periods: 37
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 21500, FO atual: 22000
# Idle Periods: 40
# Double Classes: 56
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 21500, FO atual: 23000
# Idle Periods: 41
# Double Classes: 56
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 21500, FO atual: 22500
# Idle Periods: 41
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 21500, FO atual: 22000
# Idle Periods: 41
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 21500, FO atual: 24500
# Idle Periods: 42
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 21500, FO atual: 25000
# Idle Periods: 40
# Double Classes: 50
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 21500, FO atual: 25000
# Idle Periods: 40
# Double Classes: 50
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 21500, FO atual: 26500
# Idle Periods: 42
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 21500, FO atual: 26500
# Idle Periods: 42
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 2 iterações.
# 8
# fo1: 27500
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 27500, FO atual: 20500
# Idle Periods: 13
# Double Classes: 5
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 20500, FO atual: 20000
# Idle Periods: 12
# Double Classes: 4
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 20000, FO atual: 21000
# Idle Periods: 13
# Double Classes: 4
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 20000, FO atual: 17000
# Idle Periods: 9
# Double Classes: 4
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 17000, FO atual: 16500
# Idle Periods: 8
# Double Classes: 3
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 16500, FO atual: 19500
# Idle Periods: 11
# Double Classes: 3
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 16500, FO atual: 24500
# Idle Periods: 16
# Double Classes: 3
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 16500, FO atual: 48500
# Idle Periods: 40
# Double Classes: 3
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 16500, FO atual: 53000
# Idle Periods: 45
# Double Classes: 4
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 16500, FO atual: 68000
# Idle Periods: 61
# Double Classes: 6
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 16500, FO atual: 74000
# Idle Periods: 67
# Double Classes: 6
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 16500, FO atual: 72000
# Idle Periods: 65
# Double Classes: 6
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 16500, FO atual: 60500
# Idle Periods: 54
# Double Classes: 7
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 16500, FO atual: 44500
# Idle Periods: 47
# Double Classes: 5
# Triple Classes: 0
# Nova solução rejeitada.
# Ponto ótimo alcançado em 2 iterações.
# 9
# fo1: 65000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 65000, FO atual: 59000
# Idle Periods: 75
# Double Classes: 52
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 59000, FO atual: 51000
# Idle Periods: 69
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 51000, FO atual: 44500
# Idle Periods: 63
# Double Classes: 57
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 44500, FO atual: 45500
# Idle Periods: 64
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 44500, FO atual: 37000
# Idle Periods: 56
# Double Classes: 58
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 37000, FO atual: 34000
# Idle Periods: 54
# Double Classes: 60
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 34000, FO atual: 34500
# Idle Periods: 55
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 34000, FO atual: 37500
# Idle Periods: 57
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 34000, FO atual: 38500
# Idle Periods: 57
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 34000, FO atual: 35500
# Idle Periods: 55
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 34000, FO atual: 33500
# Idle Periods: 52
# Double Classes: 57
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 33500, FO atual: 33000
# Idle Periods: 52
# Double Classes: 58
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 33000, FO atual: 41000
# Idle Periods: 60
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 33000, FO atual: 42000
# Idle Periods: 61
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 33000, FO atual: 40000
# Idle Periods: 60
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 33000, FO atual: 40500
# Idle Periods: 60
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 33000, FO atual: 43000
# Idle Periods: 63
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 33000, FO atual: 40000
# Idle Periods: 62
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 33000, FO atual: 35500
# Idle Periods: 58
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 33000, FO atual: 35000
# Idle Periods: 57
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 33000, FO atual: 38000
# Idle Periods: 60
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 3 iterações.
# 10
# fo1: 58000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 58000, FO atual: 53500
# Idle Periods: 68
# Double Classes: 49
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 53500, FO atual: 53500
# Idle Periods: 69
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 53500, FO atual: 35000
# Idle Periods: 53
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 35000, FO atual: 26500
# Idle Periods: 47
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 26500, FO atual: 29000
# Idle Periods: 49
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 26500, FO atual: 25500
# Idle Periods: 48
# Double Classes: 65
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 25500, FO atual: 21000
# Idle Periods: 44
# Double Classes: 66
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 21000, FO atual: 19000
# Idle Periods: 43
# Double Classes: 68
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 19000, FO atual: 24000
# Idle Periods: 47
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 19000, FO atual: 20500
# Idle Periods: 42
# Double Classes: 63
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 19000, FO atual: 28000
# Idle Periods: 50
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 19000, FO atual: 33000
# Idle Periods: 56
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 19000, FO atual: 33500
# Idle Periods: 56
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 19000, FO atual: 30500
# Idle Periods: 53
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 19000, FO atual: 30000
# Idle Periods: 53
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 19000, FO atual: 30500
# Idle Periods: 53
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 19000, FO atual: 30500
# Idle Periods: 54
# Double Classes: 67
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 19000, FO atual: 34000
# Idle Periods: 55
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 19000, FO atual: 36500
# Idle Periods: 57
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 19000, FO atual: 35000
# Idle Periods: 56
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 19000, FO atual: 36500
# Idle Periods: 57
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 3 iterações.
# 11
# fo1: 71000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 71000, FO atual: 70500
# Idle Periods: 81
# Double Classes: 41
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 70500, FO atual: 60000
# Idle Periods: 73
# Double Classes: 46
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 60000, FO atual: 47000
# Idle Periods: 62
# Double Classes: 50
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 47000, FO atual: 50000
# Idle Periods: 64
# Double Classes: 48
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 47000, FO atual: 51000
# Idle Periods: 67
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 47000, FO atual: 45000
# Idle Periods: 63
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 45000, FO atual: 42500
# Idle Periods: 62
# Double Classes: 59
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 42500, FO atual: 41500
# Idle Periods: 62
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 41500, FO atual: 41500
# Idle Periods: 62
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 41500, FO atual: 35500
# Idle Periods: 57
# Double Classes: 63
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 35500, FO atual: 28500
# Idle Periods: 53
# Double Classes: 69
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 28500, FO atual: 26000
# Idle Periods: 50
# Double Classes: 68
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 26000, FO atual: 35000
# Idle Periods: 58
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 26000, FO atual: 35500
# Idle Periods: 58
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 26000, FO atual: 38000
# Idle Periods: 61
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 26000, FO atual: 37000
# Idle Periods: 60
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 26000, FO atual: 35500
# Idle Periods: 59
# Double Classes: 67
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 26000, FO atual: 40500
# Idle Periods: 60
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 26000, FO atual: 37500
# Idle Periods: 56
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 26000, FO atual: 26500
# Idle Periods: 48
# Double Classes: 63
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 26000, FO atual: 27500
# Idle Periods: 49
# Double Classes: 63
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 3 iterações.
# 12
# fo1: 54000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 54000, FO atual: 55500
# Idle Periods: 70
# Double Classes: 49
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 54000, FO atual: 46000
# Idle Periods: 62
# Double Classes: 52
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 46000, FO atual: 40000
# Idle Periods: 59
# Double Classes: 58
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 40000, FO atual: 36000
# Idle Periods: 56
# Double Classes: 60
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 36000, FO atual: 39000
# Idle Periods: 58
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 36000, FO atual: 34000
# Idle Periods: 53
# Double Classes: 58
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 34000, FO atual: 33000
# Idle Periods: 52
# Double Classes: 58
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 33000, FO atual: 31500
# Idle Periods: 50
# Double Classes: 57
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 31500, FO atual: 33000
# Idle Periods: 52
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 31500, FO atual: 26000
# Idle Periods: 46
# Double Classes: 60
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 26000, FO atual: 23500
# Idle Periods: 45
# Double Classes: 63
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 23500, FO atual: 17500
# Idle Periods: 41
# Double Classes: 67
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 17500, FO atual: 18000
# Idle Periods: 42
# Double Classes: 68
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 17500, FO atual: 17000
# Idle Periods: 42
# Double Classes: 70
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 17000, FO atual: 18500
# Idle Periods: 45
# Double Classes: 73
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 17000, FO atual: 18000
# Idle Periods: 43
# Double Classes: 70
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 17000, FO atual: 18000
# Idle Periods: 42
# Double Classes: 68
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 17000, FO atual: 22000
# Idle Periods: 45
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 17000, FO atual: 23000
# Idle Periods: 45
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 17000, FO atual: 25500
# Idle Periods: 46
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 17000, FO atual: 27000
# Idle Periods: 47
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 3 iterações.
# 13
# fo1: 39000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 39000, FO atual: 29500
# Idle Periods: 45
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 29500, FO atual: 32500
# Idle Periods: 49
# Double Classes: 53
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 29500, FO atual: 38000
# Idle Periods: 55
# Double Classes: 54
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 29500, FO atual: 33000
# Idle Periods: 51
# Double Classes: 56
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 29500, FO atual: 29500
# Idle Periods: 50
# Double Classes: 61
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 29500, FO atual: 33000
# Idle Periods: 53
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 29500, FO atual: 34000
# Idle Periods: 54
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 29500, FO atual: 34500
# Idle Periods: 54
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 29500, FO atual: 36500
# Idle Periods: 57
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 29500, FO atual: 29500
# Idle Periods: 52
# Double Classes: 65
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 29500, FO atual: 24500
# Idle Periods: 48
# Double Classes: 67
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 24500, FO atual: 21500
# Idle Periods: 44
# Double Classes: 65
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 21500, FO atual: 19500
# Idle Periods: 42
# Double Classes: 65
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 19500, FO atual: 20500
# Idle Periods: 43
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 19500, FO atual: 21000
# Idle Periods: 44
# Double Classes: 66
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 19500, FO atual: 23500
# Idle Periods: 46
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 19500, FO atual: 28500
# Idle Periods: 50
# Double Classes: 63
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 19500, FO atual: 23500
# Idle Periods: 44
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 19500, FO atual: 21500
# Idle Periods: 42
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 19500, FO atual: 20000
# Idle Periods: 42
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 19500, FO atual: 22500
# Idle Periods: 45
# Double Classes: 65
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 3 iterações.
# 14
# fo1: 18500
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 18500, FO atual: 16500
# Idle Periods: 8
# Double Classes: 3
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 16500, FO atual: 17500
# Idle Periods: 9
# Double Classes: 3
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 16500, FO atual: 17500
# Idle Periods: 9
# Double Classes: 3
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 16500, FO atual: 14500
# Idle Periods: 6
# Double Classes: 3
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 14500, FO atual: 14500
# Idle Periods: 6
# Double Classes: 3
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 14500, FO atual: 17500
# Idle Periods: 9
# Double Classes: 3
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 14500, FO atual: 14000
# Idle Periods: 14
# Double Classes: 0
# Triple Classes: 0
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 14000, FO atual: 24000
# Idle Periods: 24
# Double Classes: 0
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 14000, FO atual: 28500
# Idle Periods: 29
# Double Classes: 1
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 14000, FO atual: 26000
# Idle Periods: 27
# Double Classes: 2
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 14000, FO atual: 32000
# Idle Periods: 33
# Double Classes: 2
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 14000, FO atual: 32000
# Idle Periods: 33
# Double Classes: 2
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 14000, FO atual: 25000
# Idle Periods: 26
# Double Classes: 2
# Triple Classes: 0
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 14000, FO atual: 27500
# Idle Periods: 29
# Double Classes: 3
# Triple Classes: 0
# Nova solução rejeitada.
# Ponto ótimo alcançado em 2 iterações.
# 15
# fo1: 64000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 64000, FO atual: 65000
# Idle Periods: 76
# Double Classes: 42
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 64000, FO atual: 59500
# Idle Periods: 72
# Double Classes: 45
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 59500, FO atual: 43500
# Idle Periods: 58
# Double Classes: 49
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 43500, FO atual: 27000
# Idle Periods: 43
# Double Classes: 52
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 27000, FO atual: 28000
# Idle Periods: 44
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 27000, FO atual: 25000
# Idle Periods: 40
# Double Classes: 50
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 25000, FO atual: 20500
# Idle Periods: 37
# Double Classes: 53
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 20500, FO atual: 21500
# Idle Periods: 38
# Double Classes: 53
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 20500, FO atual: 20500
# Idle Periods: 37
# Double Classes: 53
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 20500, FO atual: 29000
# Idle Periods: 45
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 20500, FO atual: 30500
# Idle Periods: 47
# Double Classes: 53
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 20500, FO atual: 22500
# Idle Periods: 40
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 20500, FO atual: 20000
# Idle Periods: 37
# Double Classes: 54
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 20000, FO atual: 19000
# Idle Periods: 37
# Double Classes: 56
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 19000, FO atual: 19500
# Idle Periods: 37
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 19000, FO atual: 20500
# Idle Periods: 38
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# ...
# Otimizando para turmas: ['3o']
# FO anterior: 23500, FO atual: 40500
# Idle Periods: 59
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 23500, FO atual: 40000
# Idle Periods: 59
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 23500, FO atual: 35500
# Idle Periods: 54
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 23500, FO atual: 36000
# Idle Periods: 55
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 23500, FO atual: 36000
# Idle Periods: 56
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 23500, FO atual: 29500
# Idle Periods: 53
# Double Classes: 67
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 23500, FO atual: 26000
# Idle Periods: 50
# Double Classes: 68
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 23500, FO atual: 21000
# Idle Periods: 45
# Double Classes: 68
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 4:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 21000, FO atual: 23000
# Idle Periods: 45
# Double Classes: 64
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 21000, FO atual: 23000
# Idle Periods: 47
# Double Classes: 68
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 21000, FO atual: 21500
# Idle Periods: 45
# Double Classes: 67
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 21000, FO atual: 32500
# Idle Periods: 54
# Double Classes: 63
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 21000, FO atual: 34500
# Idle Periods: 54
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 21000, FO atual: 38500
# Idle Periods: 57
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 21000, FO atual: 37500
# Idle Periods: 56
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 4 iterações.
# 66
# fo1: 60000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 60000, FO atual: 57500
# Idle Periods: 66
# Double Classes: 37
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 57500, FO atual: 50500
# Idle Periods: 60
# Double Classes: 39
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 50500, FO atual: 44500
# Idle Periods: 55
# Double Classes: 41
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 44500, FO atual: 40500
# Idle Periods: 52
# Double Classes: 43
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 40500, FO atual: 40000
# Idle Periods: 53
# Double Classes: 46
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 40000, FO atual: 39500
# Idle Periods: 54
# Double Classes: 49
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 39500, FO atual: 34500
# Idle Periods: 50
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 34500, FO atual: 29500
# Idle Periods: 46
# Double Classes: 53
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 29500, FO atual: 29500
# Idle Periods: 47
# Double Classes: 55
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 29500, FO atual: 32000
# Idle Periods: 51
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 29500, FO atual: 31500
# Idle Periods: 50
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 29500, FO atual: 33000
# Idle Periods: 52
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 29500, FO atual: 34000
# Idle Periods: 53
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 29500, FO atual: 36500
# Idle Periods: 56
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 29500, FO atual: 40000
# Idle Periods: 59
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 29500, FO atual: 34500
# Idle Periods: 54
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 29500, FO atual: 34500
# Idle Periods: 54
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 29500, FO atual: 35500
# Idle Periods: 55
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 29500, FO atual: 47500
# Idle Periods: 67
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 29500, FO atual: 51500
# Idle Periods: 71
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 29500, FO atual: 46000
# Idle Periods: 65
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 3 iterações.
# 67
# fo1: 75000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 75000, FO atual: 67000
# Idle Periods: 78
# Double Classes: 42
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 67000, FO atual: 64500
# Idle Periods: 76
# Double Classes: 43
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 64500, FO atual: 51500
# Idle Periods: 66
# Double Classes: 49
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 51500, FO atual: 52000
# Idle Periods: 67
# Double Classes: 50
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 51500, FO atual: 48000
# Idle Periods: 64
# Double Classes: 52
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 48000, FO atual: 47500
# Idle Periods: 63
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 47500, FO atual: 48000
# Idle Periods: 64
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 47500, FO atual: 47500
# Idle Periods: 64
# Double Classes: 53
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 47500, FO atual: 37500
# Idle Periods: 55
# Double Classes: 55
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 37500, FO atual: 38500
# Idle Periods: 55
# Double Classes: 53
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 37500, FO atual: 31500
# Idle Periods: 48
# Double Classes: 53
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 31500, FO atual: 35000
# Idle Periods: 51
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 31500, FO atual: 40500
# Idle Periods: 58
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 31500, FO atual: 39000
# Idle Periods: 57
# Double Classes: 56
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 31500, FO atual: 38000
# Idle Periods: 55
# Double Classes: 54
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 31500, FO atual: 42500
# Idle Periods: 59
# Double Classes: 53
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 31500, FO atual: 39000
# Idle Periods: 54
# Double Classes: 50
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 31500, FO atual: 36500
# Idle Periods: 52
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 31500, FO atual: 31500
# Idle Periods: 47
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 31500, FO atual: 30500
# Idle Periods: 46
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 30500, FO atual: 30500
# Idle Periods: 46
# Double Classes: 51
# Triple Classes: 2
# Nova solução aceita.
#
# Iteração 4:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 30500, FO atual: 31500
# Idle Periods: 47
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 30500, FO atual: 39500
# Idle Periods: 55
# Double Classes: 51
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 30500, FO atual: 39000
# Idle Periods: 55
# Double Classes: 52
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 30500, FO atual: 43000
# Idle Periods: 60
# Double Classes: 54
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 30500, FO atual: 45500
# Idle Periods: 63
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 30500, FO atual: 45000
# Idle Periods: 63
# Double Classes: 56
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 30500, FO atual: 48500
# Idle Periods: 66
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 4 iterações.
# 68
# fo1: 21500
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 21500, FO atual: 14500
# Idle Periods: 7
# Double Classes: 5
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 14500, FO atual: 14500
# Idle Periods: 7
# Double Classes: 5
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 14500, FO atual: 13500
# Idle Periods: 6
# Double Classes: 5
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 13500, FO atual: 8500
# Idle Periods: 1
# Double Classes: 5
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 8500, FO atual: 10000
# Idle Periods: 2
# Double Classes: 4
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 8500, FO atual: 11000
# Idle Periods: 3
# Double Classes: 4
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 8500, FO atual: 3500
# Idle Periods: 1
# Double Classes: 5
# Triple Classes: 1
# Nova solução aceita.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 3500, FO atual: 17000
# Idle Periods: 15
# Double Classes: 6
# Triple Classes: 1
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 3500, FO atual: 21500
# Idle Periods: 20
# Double Classes: 7
# Triple Classes: 1
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 3500, FO atual: 28500
# Idle Periods: 28
# Double Classes: 9
# Triple Classes: 1
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 3500, FO atual: 34500
# Idle Periods: 34
# Double Classes: 9
# Triple Classes: 1
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 3500, FO atual: 34500
# Idle Periods: 34
# Double Classes: 9
# Triple Classes: 1
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 3500, FO atual: 35500
# Idle Periods: 35
# Double Classes: 9
# Triple Classes: 1
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 3500, FO atual: 29500
# Idle Periods: 32
# Double Classes: 5
# Triple Classes: 0
# Nova solução rejeitada.
# Ponto ótimo alcançado em 2 iterações.
# 69
# fo1: 73000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 73000, FO atual: 65000
# Idle Periods: 73
# Double Classes: 36
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 65000, FO atual: 58500
# Idle Periods: 68
# Double Classes: 39
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 58500, FO atual: 45500
# Idle Periods: 58
# Double Classes: 45
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 45500, FO atual: 42000
# Idle Periods: 56
# Double Classes: 48
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 42000, FO atual: 35000
# Idle Periods: 51
# Double Classes: 52
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 35000, FO atual: 28500
# Idle Periods: 47
# Double Classes: 57
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['3o']
# FO anterior: 28500, FO atual: 29000
# Idle Periods: 48
# Double Classes: 58
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 2:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 28500, FO atual: 25500
# Idle Periods: 45
# Double Classes: 59
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 25500, FO atual: 21500
# Idle Periods: 40
# Double Classes: 57
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 21500, FO atual: 26500
# Idle Periods: 47
# Double Classes: 61
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 21500, FO atual: 33000
# Idle Periods: 54
# Double Classes: 62
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 21500, FO atual: 31000
# Idle Periods: 51
# Double Classes: 60
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 21500, FO atual: 30500
# Idle Periods: 50
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 21500, FO atual: 30500
# Idle Periods: 50
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
#
# Iteração 3:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 21500, FO atual: 37000
# Idle Periods: 55
# Double Classes: 56
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 21500, FO atual: 32500
# Idle Periods: 52
# Double Classes: 59
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 21500, FO atual: 35500
# Idle Periods: 54
# Double Classes: 57
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 21500, FO atual: 33000
# Idle Periods: 50
# Double Classes: 54
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['1oA', '1oB']
# FO anterior: 21500, FO atual: 31500
# Idle Periods: 49
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['2oA', '2oB']
# FO anterior: 21500, FO atual: 33500
# Idle Periods: 50
# Double Classes: 53
# Triple Classes: 2
# Nova solução rejeitada.
# Otimizando para turmas: ['3o']
# FO anterior: 21500, FO atual: 32500
# Idle Periods: 50
# Double Classes: 55
# Triple Classes: 2
# Nova solução rejeitada.
# Ponto ótimo alcançado em 3 iterações.
# 70
# fo1: 64000
#
# Iteração 1:
# Otimizando para turmas: ['6oA', '6oB']
# FO anterior: 64000, FO atual: 60500
# Idle Periods: 78
# Double Classes: 55
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['7oA', '7oB']
# FO anterior: 60500, FO atual: 54500
# Idle Periods: 73
# Double Classes: 57
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['8oA', '8oB']
# FO anterior: 54500, FO atual: 45000
# Idle Periods: 64
# Double Classes: 58
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['9oA', '9oB']
# FO anterior: 45000, FO atual: 32000
# Idle Periods: 54
# Double Classes: 64
# Triple Classes: 2
# Nova solução aceita.
# Otimizando para turmas: ['1oA', '1oB']
